# %% [markdown]
# <a href="https://colab.research.google.com/github/Mallikarjun1235/NLP-nlkt-/blob/main/Black_coffer_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h3> Importing the libraries

# %%
import pandas as pd
import numpy as np
import csv
import requests
from bs4 import BeautifulSoup
import nltk
nltk.download('cmudict')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt') # download the necessary NLTK tokenizer data
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.corpus import cmudict, stopwords
stop_words = set(stopwords.words('english'))
import re
from nltk.corpus import cmudict, stopwords
import spacy
nlp = spacy.load('en_core_web_sm')

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# <h3> Mounting the drive, where the excel files are stored

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
PATH='/content/gdrive/MyDrive/Black_coffer' # This PATH may not work for you , change the path according to your file sysytem
os.chdir(PATH)

# %% [markdown]
# <h2> Extracting title and text from the urls and storing the content in their respective url_id text files.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# load the URLs and URL IDs from the Excel file
df = pd.read_excel('Input.xlsx')
urls = df['URL'].tolist()
url_ids = df['URL_ID'].tolist()

# loop through each URL and extract the article title and text
for i, url in enumerate(urls):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # find the article title
    title_elem = soup.find('h1')
    if title_elem is None:
        print(f"No title found for URL ID {url_ids[i]}")
        title = ''
    else:
        title = title_elem.get_text()

    # find the article text
    article = soup.find('article')
    if article is None:
        print(f"No article found for URL ID {url_ids[i]}")
        text = ''
    else:
        # exclude footer and img tags
        for tag in article.select('footer,img'):
            tag.decompose()

        # extract text from remaining tags
        text = ''
        for p in article.find_all(['p', 'ol', 'ul'], recursive=True):
            text += p.get_text(strip=True) + '\n'

    # save the title and text to a file with the URL ID as its name
    url_id = url_ids[i]
    with open(f"{'url_'+str(url_id)}.txt", 'w', encoding='utf-8') as f:
        f.write(title + '\n\n' + text)
# Out:
# No title found for URL ID 44
# No article found for URL ID 44
# No title found for URL ID 57
# No article found for URL ID 57
# No title found for URL ID 144
# No article found for URL ID 144

# %% [markdown]
# <h4> Lets see the content from url_56 file

# %%
with open('url_56.txt', 'r') as f:
        content =f.read()
        print(content)
# Out:
# How Data Analytics can help your business respond to the impact of COVID-19?
#
# BlackcofferWhat We ThinkHealthcarePharmaceuticals, Biotechnology & Life Sciences
# Before we get into the whole discussion, let’s first discuss the basic working of data analysis.
# Data analysisis defined as a process of cleaning, transforming, and modeling data to discover useful information for business decision-making.
# Using data analysis, we can extract useful information from the given data and then take corresponding decisions based upon the analyzed data.
# During the pandemic known as COVID-19, many businesses failed to grow whereas many touched the sky, for example, the transportation of raw materials was drastically low because:
# The nationwide lockdown was imposed,Low production due to a smaller number of workers,Storage facilities were shut down, and many more for such reasons.
# ...

# %% [markdown]
# <h2> Importing positive-word , negative-word text files

# %%
with open('positive-words.txt', 'r') as f:
        positive =f.read()
        print(positive)
# Out:
# a+
# abound
# abounds
# abundance
# abundant
# accessable
# accessible
# acclaim
# acclaimed
# acclamation
# accolade
# accolades
# accommodative
# accomodative
# accomplish
# accomplished
# accomplishment
# accomplishments
# accurate
# accurately
# achievable
# achievement
# achievements
# achievible
# acumen
# adaptable
# adaptive
# adequate
# adjustable
# admirable
# admirably
# admiration
# admire
# admirer
# admiring
# admiringly
# adorable
# adore
# adored
# adorer
# adoring
# adoringly
# adroit
# adroitly
# adulate
# adulation
# adulatory
# advanced
# advantage
# advantageous
# advantageously
# advantages
# adventuresome
# adventurous
# advocate
# advocated
# advocates
# affability
# affable
# affably
# affectation
# affection
# affectionate
# affinity
# affirm
# affirmation
# affirmative
# affluence
# affluent
# afford
# affordable
# affordably
# afordable
# agile
# agilely
# agility
# agreeable
# agreeableness
# agreeably
# all-around
# alluring
# alluringly
# altruistic
# ...

# %%
with open('negative-words.txt', 'r',encoding='latin-1') as f:
        negative =f.read()
        print(negative)
# Out:
# 2-faced
# 2-faces
# abnormal
# abolish
# abominable
# abominably
# abominate
# abomination
# abort
# aborted
# aborts
# abrade
# abrasive
# abrupt
# abruptly
# abscond
# absence
# absent-minded
# absentee
# absurd
# absurdity
# absurdly
# absurdness
# abuse
# abused
# abuses
# abusive
# abysmal
# abysmally
# abyss
# accidental
# accost
# accursed
# accusation
# accusations
# accuse
# accuses
# accusing
# accusingly
# acerbate
# acerbic
# acerbically
# ache
# ached
# aches
# achey
# aching
# acrid
# acridly
# acridness
# acrimonious
# acrimoniously
# acrimony
# adamant
# adamantly
# addict
# addicted
# addicting
# addicts
# admonish
# admonisher
# admonishingly
# admonishment
# admonition
# adulterate
# adulterated
# adulteration
# adulterier
# adversarial
# adversary
# adverse
# adversity
# afflict
# affliction
# afflictive
# affront
# afraid
# aggravate
# aggravating
# aggravation
# aggression
# aggressive
# aggressiveness
# aggressor
# aggrieve
# aggrieved
# aggrivation
# aghast
# ...

# %% [markdown]
# <h2> Extracting text from urls and calculating 'Positive Score', 'Negative Score', 'Polarity Score', 'Subjectivity Score'

# %%
# load the URLs and URL IDs from the Excel file
df = pd.read_excel('Input.xlsx')
urls = df['URL'].tolist()
url_ids = df['URL_ID'].tolist()

# load the positive and negative dictionaries
with open('positive-words.txt', 'r', encoding='utf-8') as f:
    positive = set(f.read().splitlines())

with open('negative-words.txt', 'r', encoding='latin-1') as f:
    negative = set(f.read().splitlines())

# create a list to store the scores for each URL
scores = []

# loop through each URL and extract the article title and text
for i, url in enumerate(urls):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # find the article title
    title_elem = soup.find('h1')
    if title_elem is None:
        print(f"No title found for URL ID {url_ids[i]}")
        title = ''
    else:
        title = title_elem.get_text()

    # find the article text
    article = soup.find('article')
    if article is None:
        print(f"No article found for URL ID {url_ids[i]}")
        text = ''
    else:
        # exclude footer and img tags
        for tag in article.select('footer,img'):
            tag.decompose()

        # extract text from remaining tags
        text = ''
        for p in article.find_all(['p', 'ol', 'ul'], recursive=True):
            text += p.get_text(strip=True) + ' '

        # tokenize the text using NLTK
        tokens = nltk.word_tokenize(text)

        # calculate the scores
        pos_score = sum([1 for word in tokens if word in positive])
        neg_score = sum([1 for word in tokens if word in negative]) * -1
        polarity_score = min(max((pos_score - neg_score) / (pos_score + neg_score + 0.000001), -1), 1)
        subjectivity_score = (pos_score + neg_score) / ((len(tokens) + 0.000001))

        # add the scores to the list
        scores.append([url_ids[i], pos_score, neg_score, polarity_score, subjectivity_score])

# write the scores to a CSV file
with open('scores.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['URL_ID', 'Positive Score', 'Negative Score', 'Polarity Score', 'Subjectivity Score'])
    writer.writerows(scores)
# Out:
# No title found for URL ID 44
# No article found for URL ID 44
# No title found for URL ID 57
# No article found for URL ID 57
# No title found for URL ID 144
# No article found for URL ID 144

# %% [markdown]
# <h3> stroring those scores in 'score.csv file'

# %%
 scores =pd.read_csv('scores.csv')

# %%
scores.head(10)
# Out:
#    URL_ID  Positive Score  Negative Score  Polarity Score  Subjectivity Score
# 0      37              76             -33             1.0            0.021586
# 1      38              65             -38             1.0            0.016494
# 2      39              72             -35             1.0            0.019412
# 3      40              71             -24             1.0            0.026659
# 4      41              57             -24             1.0            0.017002
# 5      42              53             -23             1.0            0.020979
# 6      43              27             -12             1.0            0.017986
# 7      45              43             -13             1.0            0.037453
# 8      46              77             -40             1.0            0.015353
# 9      47              56             -60            -1.0           -0.001795

# %% [markdown]
# <h2> Extracting text from urls and calculating 'Average Sentence Length', 'Percentage of Complex Words', 'Fog Index'

# %%
import csv
import pandas as pd
import requests
from bs4 import BeautifulSoup
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt') # download the necessary NLTK tokenizer data

# load the URLs and URL IDs from the Excel file
df = pd.read_excel('Input.xlsx')
urls = df['URL'].tolist()
url_ids = df['URL_ID'].tolist()

# load the positive and negative dictionaries
with open('positive-words.txt', 'r', encoding='utf-8') as f:
    positive = set(f.read().splitlines())

with open('negative-words.txt', 'r', encoding='latin-1') as f:
    negative = set(f.read().splitlines())

# create a list to store the scores for each URL
Reliability_score = []

# loop through each URL and extract the article title and text
for i, url in enumerate(urls):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # find the article title
    title_elem = soup.find('h1')
    if title_elem is None:
        print(f"No title found for URL ID {url_ids[i]}")
        title = ''
    else:
        title = title_elem.get_text()

    # find the article text
    article = soup.find('article')
    if article is None:
        print(f"No article found for URL ID {url_ids[i]}")
        text = ''
    else:
        # exclude footer and img tags
        for tag in article.select('footer,img'):
            tag.decompose()

        # extract text from remaining tags
        text = ''
        for p in article.find_all(['p', 'ol', 'ul'], recursive=True):
            text += p.get_text(strip=True) + ' '

        # tokenize the text using NLTK
        tokens = nltk.word_tokenize(text)

       

       
        # calculate the Gunning Fox index
        sentences = nltk.sent_tokenize(text)
        num_sentences = len(sentences)
        num_words = len(tokens)
        num_complex_words = len([word for word in tokens if len(word) > 2 and word.isalpha() and len(nltk.pos_tag([word])[0][1]) > 1])
        avg_sentence_length = num_words / num_sentences
        percent_complex_words = num_complex_words / num_words
        fog_index = 0.4 * (avg_sentence_length + percent_complex_words)

        # add the scores and Gunning Fox index to the list
        Reliability_score.append([url_ids[i], avg_sentence_length, percent_complex_words, fog_index])

# write the scores to a CSV file
with open('Reliability_score.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['URL_ID', 'Average Sentence Length', 'Percentage of Complex Words', 'Fog Index'])
    writer.writerows(Reliability_score)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# No title found for URL ID 44
# No article found for URL ID 44
# No title found for URL ID 57
# No article found for URL ID 57
# No title found for URL ID 144
# No article found for URL ID 144

# %% [markdown]
# storing the 'Average Sentence Length', 'Percentage of Complex Words', 'Fog Index' values in 'Reliability.csv'

# %%
Reliability_score = pd.read_csv('Reliability_score.csv')
Reliability_score.head()
# Out:
#    URL_ID  Average Sentence Length  Percentage of Complex Words  Fog Index
# 0      37                26.210526                     0.719378  10.771962
# 1      38                20.721519                     0.668907   8.556170
# 2      39                22.690476                     0.700420   9.356358
# 3      40                19.373626                     0.686897   8.024209
# 4      41                25.207792                     0.683153  10.356378

# %%
Reliability_score.shape
# Out:
# (111, 4)

# %% [markdown]
# <h2> Extracting text from urls and calculating 'Average Number of Words per Sentence', 'Complex Word Count', 'Word Count'

# %%
# load the URLs and URL IDs from the Excel file
df = pd.read_excel('Input.xlsx')
urls = df['URL'].tolist()
url_ids = df['URL_ID'].tolist()

# create a list to store the scores for each URL
word_count = []

# load the CMU Pronouncing Dictionary
cmudict = nltk.corpus.cmudict.dict()

# loop through each URL and extract the article title and text
for i, url in enumerate(urls):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # find the article title
    title_elem = soup.find('h1')
    if title_elem is None:
        print(f"No title found for URL ID {url_ids[i]}")
        title = ''
    else:
        title = title_elem.get_text()

    # find the article text
    article = soup.find('article')
    if article is None:
        print(f"No article found for URL ID {url_ids[i]}")
        text = ''
    else:
        # exclude footer and img tags
        for tag in article.select('footer,img'):
            tag.decompose()

        # extract text from remaining tags
        text = ''
        for p in article.find_all(['p', 'ol', 'ul'], recursive=True):
            text += p.get_text(strip=True) + ' '

        # tokenize the text using NLTK
        tokens = nltk.word_tokenize(text)

        # remove stop words and punctuation from tokens
        words = [word.lower() for word in tokens if word.lower() not in stop_words and word.isalpha()]

        # calculate the average number of words per sentence
        sentences = nltk.sent_tokenize(text)
        num_sentences = len(sentences)
        num_words = len(words)
        avg_num_words_per_sentence = num_words / num_sentences

        # calculate the complex word count
        complex_words = []
        for word in words:
            if word in cmudict and len(cmudict[word][0]) > 2:
                complex_words.append(word)
        num_complex_words = len(complex_words)

        # calculate the word count
        num_words = len(words)

        # add the scores to the list
        word_count.append([url_ids[i], avg_num_words_per_sentence, num_complex_words, num_words])

# write the scores to a CSV file
with open('word_count.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['URL_ID', 'Average Number of Words per Sentence', 'Complex Word Count', 'Word Count'])
    writer.writerows(word_count)
# Out:
# No title found for URL ID 44
# No article found for URL ID 44
# No title found for URL ID 57
# No article found for URL ID 57
# No title found for URL ID 144
# No article found for URL ID 144

# %% [markdown]
# <hw> storing 'Average Number of Words per Sentence', 'Complex Word Count', 'Word Count' values in 'word_count.csv'

# %%
word_count = pd.read_csv('word_count.csv')
word_count.head()
# Out:
#    URL_ID  Average Number of Words per Sentence  Complex Word Count  \
# 0      37                             14.421053                1009
# 1      38                              9.253165                 678
# 2      39                             11.666667                 926
# 3      40                              9.340659                 763
# 4      41                             11.818182                 860
#
#    Word Count
# 0        1096
# 1         731
# 2         980
# 3         850
# 4         910

# %% [markdown]
# <h2> Extracting text from urls and calculating 'Syllable Count' ,'Personal Pronoun Count', 'Average Word Length'

# %%
from nltk.corpus import cmudict, stopwords
# load the URLs and URL IDs from the Excel file
df = pd.read_excel('Input.xlsx')
urls = df['URL'].tolist()
url_ids = df['URL_ID'].tolist()

# create a list to store the scores for each URL
syllable_word_count = []

# load the CMU Pronouncing Dictionary
cmudict_dict = cmudict.dict()

# define regex pattern for personal pronouns
pronoun_pattern = re.compile(r'\b(I|we|my|mine|our|ours|us)\b', re.IGNORECASE)

# loop through each URL and extract the article title and text
for i, url in enumerate(urls):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # find the article title
    title_elem = soup.find('h1')
    if title_elem is None:
        print(f"No title found for URL ID {url_ids[i]}")
        title = ''
    else:
        title = title_elem.get_text()

    # find the article text
    article = soup.find('article')
    if article is None:
        print(f"No article found for URL ID {url_ids[i]}")
        text = ''
    else:
        # exclude footer and img tags
        for tag in article.select('footer,img'):
            tag.decompose()

        # extract text from remaining tags
        text = ''
        for p in article.find_all(['p', 'ol', 'ul'], recursive=True):
            text += p.get_text(strip=True) + ' '

        # tokenize the text using NLTK
        tokens = nltk.word_tokenize(text)

        # remove stop words and punctuation from tokens, and count syllables per word
        syllable_count = 0
        total_word_length = 0
        num_words = 0
        for word in tokens:
            if word.lower() not in stopwords.words('english') and word.isalpha():
                # count number of syllables in word
                if word.endswith('es') or word.endswith('ed'):
                    syllable_count += max(1, sum([1 for c in word if c.lower() in 'aeiou']))
                else:
                    syllable_count += max(1, len(re.findall(r'[aeiouy]+', word.lower())))

                # calculate total word length
                total_word_length += len(word)
                num_words += 1

        # calculate the personal pronoun count
        personal_pronouns = len(re.findall(pronoun_pattern, text))

        # calculate the average word length
        avg_word_length = total_word_length / num_words if num_words > 0 else 0

        # add the scores to the list
        syllable_word_count.append([url_ids[i], syllable_count,personal_pronouns, avg_word_length])

# write the scores to a CSV file
# write the scores to a CSV file
with open('syllable_word_count.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['URL_ID', 'Syllable Count' ,'Personal Pronoun Count', 'Average Word Length'])
    writer.writerows(syllable_word_count)
# Out:
# No title found for URL ID 44
# No article found for URL ID 44
# No title found for URL ID 57
# No article found for URL ID 57
# No title found for URL ID 144
# No article found for URL ID 144

# %% [markdown]
# <h2> storing the 'Syllable Count' ,'Personal Pronoun Count', 'Average Word Length' values in 'syllable_word_count.csv'

# %%
syllable_word_count = pd.read_csv('syllable_word_count.csv')
syllable_word_count.head()
# Out:
#    URL_ID  Syllable Count  Personal Pronoun Count  Average Word Length
# 0      37            2787                       4             7.167883
# 1      38            1698                      10             6.541724
# 2      39            2579                       4             7.266327
# 3      40            1962                      24             6.451765
# 4      41            2217                      19             6.887912

# %% [markdown]
# <h2> Now merging all these values based on 'URL_ID' to one dataset i.e. scores , Reliability_score , word_count , syllable_word_count

# %% [markdown]
# <h3> merge of scores and reliatibility_score based on 'URL_ID' and stored it 't1' variable

# %%
t1 = pd.merge(scores,Reliability_score , on  = 'URL_ID')

# %%
t1.head(10)
# Out:
#    URL_ID  Positive Score  Negative Score  Polarity Score  Subjectivity Score  \
# 0      37              76             -33             1.0            0.021586
# 1      38              65             -38             1.0            0.016494
# 2      39              72             -35             1.0            0.019412
# 3      40              71             -24             1.0            0.026659
# 4      41              57             -24             1.0            0.017002
# 5      42              53             -23             1.0            0.020979
# 6      43              27             -12             1.0            0.017986
# 7      45              43             -13             1.0            0.037453
# 8      46              77             -40             1.0            0.015353
# 9      47              56             -60            -1.0           -0.001795
#
#    Average Sentence Length  Percentage of Complex Words  Fog Index
# ...

# %% [markdown]
# <h3> merge of word_count and syllable_word_count based on 'URL_ID' and stored it 't2' variable

# %%
t2 = pd.merge(word_count , syllable_word_count, on = 'URL_ID')

# %%
t2.head()
# Out:
#    URL_ID  Average Number of Words per Sentence  Complex Word Count  \
# 0      37                             14.421053                1009
# 1      38                              9.253165                 678
# 2      39                             11.666667                 926
# 3      40                              9.340659                 763
# 4      41                             11.818182                 860
#
#    Word Count  Syllable Count  Personal Pronoun Count  Average Word Length
# 0        1096            2787                       4             7.167883
# 1         731            1698                      10             6.541724
# 2         980            2579                       4             7.266327
# 3         850            1962                      24             6.451765
# 4         910            2217                      19             6.887912

# %% [markdown]
# Now merging 't1' and 't2' i.e. mergeing of all four scores , Reliability_score , word_count , syllable_word_count based on 'URL_ID'

# %%
T1 = pd.merge(t1,t2, on ='URL_ID')
T1.head()
# Out:
#    URL_ID  Positive Score  Negative Score  Polarity Score  Subjectivity Score  \
# 0      37              76             -33             1.0            0.021586
# 1      38              65             -38             1.0            0.016494
# 2      39              72             -35             1.0            0.019412
# 3      40              71             -24             1.0            0.026659
# 4      41              57             -24             1.0            0.017002
#
#    Average Sentence Length  Percentage of Complex Words  Fog Index  \
# 0                26.210526                     0.719378  10.771962
# 1                20.721519                     0.668907   8.556170
# 2                22.690476                     0.700420   9.356358
# 3                19.373626                     0.686897   8.024209
# 4                25.207792                     0.683153  10.356378
#
#    Average Number of Words per Sentence  Complex Word Count  Word Count  \
# ...

# %% [markdown]
# <h3> The final output should be in tha from Output Data Structure.xlsx, so importing that dataset for refernce

# %%
t3 = pd.read_excel('Output Data Structure.xlsx')
t3.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...             NaN
# 1      38  https://insights.blackcoffer.com/what-if-the-c...             NaN
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...             NaN
# 3      40  https://insights.blackcoffer.com/will-machine-...             NaN
# 4      41  https://insights.blackcoffer.com/will-ai-repla...             NaN
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0             NaN             NaN                 NaN                  NaN
# 1             NaN             NaN                 NaN                  NaN
# 2             NaN             NaN                 NaN                  NaN
# 3             NaN             NaN                 NaN                  NaN
# 4             NaN             NaN                 NaN                  NaN
#
# ...

# %%
t3.columns
# Out:
# Index(['URL_ID', 'URL', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE',
#        'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH',
#        'PERCENTAGE OF COMPLEX WORDS', 'FOG INDEX',
#        'AVG NUMBER OF WORDS PER SENTENCE', 'COMPLEX WORD COUNT', 'WORD COUNT',
#        'SYLLABLE PER WORD', 'PERSONAL PRONOUNS', 'AVG WORD LENGTH'],
#       dtype='object')

# %% [markdown]
# <h3> Dropping all columns except 'ULR_ID' , 'URL' because those are the representatives of the output

# %%
t3 =t3.drop(['POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE',
       'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH',
       'PERCENTAGE OF COMPLEX WORDS', 'FOG INDEX',
       'AVG NUMBER OF WORDS PER SENTENCE', 'COMPLEX WORD COUNT', 'WORD COUNT',
       'SYLLABLE PER WORD', 'PERSONAL PRONOUNS', 'AVG WORD LENGTH'],axis=1)

# %%
t3.head()
# Out:
#    URL_ID                                                URL
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...
# 1      38  https://insights.blackcoffer.com/what-if-the-c...
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...
# 3      40  https://insights.blackcoffer.com/will-machine-...
# 4      41  https://insights.blackcoffer.com/will-ai-repla...

# %% [markdown]
# <h3>As Output Data Structure is in excel format converting it into csv file to merge the results with 'URL_ID' and 'URL'

# %%
t3.to_csv('T2.csv', index=False)

# %%
T2 = pd.read_csv('T2.csv')

# %%
T2.head(10)
# Out:
#    URL_ID                                                URL
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...
# 1      38  https://insights.blackcoffer.com/what-if-the-c...
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...
# 3      40  https://insights.blackcoffer.com/will-machine-...
# 4      41  https://insights.blackcoffer.com/will-ai-repla...
# 5      42  https://insights.blackcoffer.com/man-and-machi...
# 6      43  https://insights.blackcoffer.com/in-future-or-...
# 7      44  https://insights.blackcoffer.com/how-neural-ne...
# 8      45  https://insights.blackcoffer.com/how-machine-l...
# 9      46  https://insights.blackcoffer.com/deep-learning...

# %% [markdown]
# <h3> Now to have final result merging the 'ULR_ID' and 'URL' with final results. so now we have our desired output in csv file.

# %%
final_result = pd.merge(T2,T1, on='URL_ID')

# %%
final_result.head(20)
# Out:
#     URL_ID                                                URL  Positive Score  \
# 0       37  https://insights.blackcoffer.com/ai-in-healthc...              76
# 1       38  https://insights.blackcoffer.com/what-if-the-c...              65
# 2       39  https://insights.blackcoffer.com/what-jobs-wil...              72
# 3       40  https://insights.blackcoffer.com/will-machine-...              71
# 4       41  https://insights.blackcoffer.com/will-ai-repla...              57
# 5       42  https://insights.blackcoffer.com/man-and-machi...              53
# 6       43  https://insights.blackcoffer.com/in-future-or-...              27
# 7       45  https://insights.blackcoffer.com/how-machine-l...              43
# 8       46  https://insights.blackcoffer.com/deep-learning...              77
# 9       47  https://insights.blackcoffer.com/how-to-protec...              56
# 10      48  https://insights.blackcoffer.com/how-machines-...              44
# ...

# %%
final_result.to_csv('Final_Ouput Data Structure.csv', index=False)

# %%
Final_ouput = pd.read_csv('Final_Ouput Data Structure.csv')

# %% [markdown]
# ## Note : url_44 ,url_57, url_144 has no title, no text i.e. these url does not contain any content.

# %%
Final_ouput.head()
# Out:
#    URL_ID                                                URL  Positive Score  \
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...              76
# 1      38  https://insights.blackcoffer.com/what-if-the-c...              65
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...              72
# 3      40  https://insights.blackcoffer.com/will-machine-...              71
# 4      41  https://insights.blackcoffer.com/will-ai-repla...              57
#
#    Negative Score  Polarity Score  Subjectivity Score  \
# 0             -33             1.0            0.021586
# 1             -38             1.0            0.016494
# 2             -35             1.0            0.019412
# 3             -24             1.0            0.026659
# 4             -24             1.0            0.017002
#
#    Average Sentence Length  Percentage of Complex Words  Fog Index  \
# 0                26.210526                     0.719378  10.771962
# ...
